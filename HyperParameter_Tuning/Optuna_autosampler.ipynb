# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ["PIP_CONSTRAINT"] = "/tmp/numpy_constraint.txt"
# !echo "numpy==1.26.4" > /tmp/numpy_constraint.txt

# !pip uninstall -y torch torchaudio torchvision \
    torchao torchcodec torchdata torchtune torchsummary -q 2>/dev/null

# !pip uninstall -y tensorflow tensorflow-text tensorflow-hub tf-keras \
    tensorflow_decision_forests tensorflow-probability \
    tensorflow-datasets tensorflow-metadata -q 2>/dev/null

# !pip uninstall -y numpy scikit-learn shap xgboost lightgbm dask \
    seaborn plotly openpyxl Cython catboost interpret lime -q 2>/dev/null

# !pip install numpy==1.26.4 -q
# !pip install scikit-learn==1.6.1 -q
# !pip install torch==2.9.0 -q

# !pip install lightgbm==4.6.0 -q
# !pip install xgboost==3.1.2 -q
# !pip install catboost==1.2.8 -q
# !pip install gpboost==1.6.1 -q
# !pip install ngboost==0.5.8 -q
# !pip install pgbm==2.2.0 -q
# !pip install pytorch-tabnet2==4.5.3 -q

# !pip install bayesian-optimization==3.2.0 -q
# !pip install optuna==4.6.0 -q
# !pip install optunahub==0.4.0 -q
# !pip install cmaes==0.12.0 -q

# !pip install shap==0.44.0 -q
# !pip install lime==0.2.0.1 -q
# !pip install interpret==0.7.4 -q

# !pip install mapie==0.6.0 -q
# !pip install puncc==0.8.0 -q
# !pip install skorch==1.3.1 -q
# !pip install properscoring==0.1 -q

# !pip install dask[dataframe]==2025.12.0 -q
# !pip install cython==3.0.12 -q
# !pip install seaborn==0.13.2 -q
# !pip install plotly==5.24.1 -q
# !pip install kaleido==1.2.0 -q
# !pip install openpyxl==3.1.5 -q
# !pip install XlsxWriter==3.2.9 -q
# !pip install cp==2020.12.3 -q

# !pip install numpy==1.26.4 --force-reinstall --no-deps -q

os._exit(0)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 54.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, which is not installed.
# splot 1.1.7 requires seaborn>=0.11.0, which is not installed.
# umap-learn 0.5.11 requires scikit-learn>=1.6, which is not installed.
# geemap 0.35.3 requires plotly, which is not installed.
# pysal 25.7 requires scikit-learn>=1.1, which is not installed.
# librosa 0.11.0 requires scikit-learn>=1.1.0, which is not installed.
# esda 2.8.1 requires scikit-learn>=1.4, which is not installed.
# segregation 2.5.3 requires scikit-learn>=0.21.3, which is not installed.
# segregation 2.5.3 requires seaborn, which is not installed.
# sentence-transformers 5.2.3 requires scikit-learn, which is not installed.
# sentence-transformers 5.2.3 requires torch>=1.11.0, which is not installed.
# mapclassify 2.10.0 requires scikit-learn>=1.4, which is not installed.
# pynndescent 0.6.0 requires scikit-learn>=0.18, which is not installed.
# accelerate 1.12.0 requires torch>=2.0.0, which is not installed.
# spopt 0.7.0 requires scikit-learn>=1.4.0, which is not installed.
# missingno 0.5.2 requires seaborn, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# cufflinks 0.17.3 requires plotly>=4.1.1, which is not installed.
# libpysal 4.14.1 requires scikit-learn>=1.4.0, which is not installed.
# keras-hub 0.21.1 requires tensorflow-text; platform_system != "Windows", which is not installed.
# imbalanced-learn 0.14.1 requires scikit-learn<2,>=1.4.2, which is not installed.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, which is not installed.
# fastai 2.8.7 requires scikit-learn, which is not installed.
# fastai 2.8.7 requires torch<3,>=1.10, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# peft 0.18.1 requires torch>=1.13.0, which is not installed.
# giddy 2.3.8 requires seaborn, which is not installed.
# hdbscan 0.8.41 requires scikit-learn>=1.6, which is not installed.
# tsfresh 0.21.1 requires scikit-learn>=0.22.0, which is not installed.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# dopamine-rl 4.1.2 requires tensorflow-probability>=0.13.0, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# spreg 1.8.5 requires scikit-learn>=0.22, which is not installed.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 68.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segregation 2.5.3 requires seaborn, which is not installed.
# sentence-transformers 5.2.3 requires torch>=1.11.0, which is not installed.
# fastai 2.8.7 requires torch<3,>=1.10, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# giddy 2.3.8 requires seaborn, which is not installed.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 952.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 759.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 6.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.25 requires torchvision, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 75.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 26.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.1/409.1 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 9.2 MB/s eta 0:00:00
#   Building wheel for autograd-gamma (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 13.2 MB/s eta 0:00:00
#   Building wheel for pgbm (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for shap (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 35.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 72.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 17.2 MB/s eta 0:00:00
#   Building wheel for dash-cytoscape (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 34.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for cp (setup.py) ... done

# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
import gpboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
from pytorch_tabnet import TabNetRegressor

# %%
# Go to find & replace button and replace (Data_folder) with your folder name. Rename your train and test dataset as train.csv and test.csv.
# Modify the names of the feature in the below cell.
# Replace (Y_Label) with actual data label name.

# %%
feature_names = ['D','L','N30_Ava','Cu_Ava','N30_Base','Cu_Base','UL','Q']

# %%
train_data_path = "./drive/MyDrive/pile_load_gendy_data/Data/train.csv"
test_data_path = "./drive/MyDrive/pile_load_gendy_data/Data/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (371, 9)
# First 5 rows of training data:
#       D     L    N30_Ava      Cu_Ava  N30_Base  Cu_Base  UL       Q      S_exp
# 0  1.0  43.5   3.317241  105.408046        50      0.0   1     0.00   0.000000
# 1  0.8  24.0   8.875000   17.708333         0     50.0   1   675.00   0.691250
# 2  0.8  24.0   5.032258   20.000000         0     40.0   1  1012.50   0.870417
# 3  1.2  70.0  18.214286   14.142857        50      0.0   2  7485.15  19.161300
# 4  1.0  34.0   6.741176   89.117647        50      0.0   2  3007.59   6.552300
#
# Shape of test data: (186, 9)
# First 5 rows of test data:
#       D     L    N30_Ava     Cu_Ava  N30_Base  Cu_Base  UL        Q     S_exp
# 0  0.8  24.0   8.875000  17.708333         0     50.0   2  1687.500  3.295000
# 1  1.0  38.0  26.631579  49.539474        50      0.0   2  2250.000  4.595960
# 2  0.8  24.0   5.032258  20.000000         0     40.0   1  1687.500  1.721250
# 3  1.0  35.5  28.400000  36.676056        50      0.0   1   741.259  0.441964
# 4  1.2  57.0  10.015789  55.842105        50      0.0   1     0.000  0.000000

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (371, 8)
# Shape of y_train: (371,)
# Shape of X_test: (186, 8)
# Shape of y_test: (186,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[ 0.11501862  0.7026739  -1.39285389  2.03926221  0.47278688 -0.36847246
#   -0.88040878 -0.93211799]
#  [-1.33640677 -0.87840793 -0.78031847 -0.77862641 -1.76108898  0.85111254
#   -0.88040878 -0.72895693]
#  [-1.33640677 -0.87840793 -1.2038373  -0.70499262 -1.76108898  0.60719554
#   -0.88040878 -0.6273764 ]
#  [ 1.566444    2.85132356  0.24898912 -0.89318909  0.47278688 -0.36847246
#    1.13583602  1.32075756]
#  [ 0.11501862 -0.06759674 -1.0154929   1.5158337   0.47278688 -0.36847246
#    1.13583602 -0.02689552]]
#
# First five rows of normalized X_test:
# [[-1.33640677 -0.87840793 -0.78031847 -0.77862641 -1.76108898  0.85111254
#    1.13583602 -0.42421534]
#  [ 0.11501862  0.25672774  1.1766814   0.2441433   0.47278688 -0.36847246
#    1.13583602 -0.25491446]
#  [-1.33640677 -0.87840793 -1.2038373  -0.70499262 -1.76108898  0.60719554
#   -0.88040878 -0.42421534]
#  [ 0.11501862  0.05402494  1.37158379 -0.16917252  0.47278688 -0.36847246
#   -0.88040878 -0.70901434]
#  [ 1.566444    1.79726901 -0.65458908  0.44665379  0.47278688 -0.36847246
#   -0.88040878 -0.93211799]]

# %% [markdown]
# # **Functions**

# %%
# Define the model classes
model_classes = {
    'Random Forest': RandomForestRegressor,
    'Gradient Boosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'LightGBM': LGBMRegressor,
    'GPBoost': GPBoostRegressor,
    'CatBoost': CatBoostRegressor,
    'HistGradientBoosting': HistGradientBoostingRegressor,
    'TabNet': TabNetRegressor,
    'NGBoost': NGBRegressor
}

# %%
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    plt.savefig(rmse_image_path)
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    plt.savefig(corr_image_path)
    plt.close()

    # Load the existing Excel file
    workbook = load_workbook(excel_file_path)

    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    workbook.save(excel_file_path)

    # Clean up the image files
    os.remove(rmse_image_path)
    os.remove(corr_image_path)

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = dict(model_info['best_params'])  # don't mutate original!
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        # ------- Main model fit logic ---------
        if model_name == "TabNet":
            # TabNet: reshape y, fit, flatten pred for LIME/SHAP, etc.
            y_train_tabnet = np.array(y_train).reshape(-1, 1)
            try:
                model = model_class(**{k: v for k, v in best_params.items() if k != "verbose"})
            except TypeError:
                model = model_class()
            model.fit(np.array(X_train), y_train_tabnet, max_epochs=100, patience=10, batch_size=1024, eval_set=[(np.array(X_train), y_train_tabnet)])
            def predict_fn(data):
                preds = model.predict(np.array(data))
                # flatten for interpreters
                return preds.flatten()
        else:
            try:
                model = model_class(**best_params)
            except TypeError:
                model = model_class()
            model.fit(X_train, y_train)
            def predict_fn(data):
                return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)
        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)
        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            feature_importances_shap = {}

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(image_path)
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            workbook = load_workbook(excel_file_path)
            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores if available
            if feature_importances_shap:
                scores_sheet.append(['Feature', 'SHAP Importance'])
                for feature, importance in feature_importances_shap.items():
                    scores_sheet.append([feature, importance])

            # Save the workbook
            workbook.save(excel_file_path)

            # Clean up the image file
            os.remove(image_path)

# %% [markdown]
# # **Hyperparameter tuning using Autosampler by Optuna**

# %%
import joblib

def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss


def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # ================= NEW =================
    model_save_dir = "./drive/MyDrive/pile_load_gendy_data/HyperParameter_Tuning/models"
    os.makedirs(model_save_dir, exist_ok=True)
    best_rmse_tracker = {}
    # =======================================

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'TabNet': (TabNetRegressor, {
            'n_d': [8, 16, 32, 64],
            'n_a': [8, 16, 32, 64],
            'n_steps': [3, 5, 7, 10],
            'gamma': [1.0, 1.3, 1.5, 2.0],
            'lambda_sparse': [1e-4, 1e-3, 1e-2],
            'optimizer_params': [{'lr': 2e-2}], # Fixed learning rate as recommended
            'mask_type': ['sparsemax', 'entmax'],
            'n_shared': [1, 2, 3],
            'n_independent': [1, 2, 3],
            'scheduler_params': [{"step_size": 10, "gamma": 0.9}],
            'scheduler_fn': [torch.optim.lr_scheduler.StepLR],
            'seed': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {})
    }

    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})
    timing_records = []

    for model_name, (model_class, param_space) in models.items():

        rmse_trial_history = {p.__class__.__name__: [] for p in pruners}

        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            start_time = time.time()

            best_rmse_tracker[(model_name, pruner_name)] = np.inf

            sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
            study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

            if model_name == 'PGBM':

                def pgbm_objective(trial):
                    params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                    model = PGBM()
                    model.train((X_train, y_train),
                                objective=mseloss_objective,
                                metric=rmseloss_metric,
                                params=params)

                    y_pred = model.predict(X_test)
                    mse = mean_squared_error(y_test, y_pred)
                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        joblib.dump(model, save_path)

                    return mse

                study.optimize(pgbm_objective, n_trials=50)

            else:

                def objective(trial):
                    params = {}
                    for key, values in param_space.items():
                        params[key] = trial.suggest_categorical(key, values)

                    model = model_class(**params)

                    if model_name == 'TabNet':
                        model.fit(X_train, y_train.reshape(-1, 1))
                    else:
                        model.fit(X_train, y_train)


                    y_pred = model.predict(X_test)

                    if model_name == 'TabNet':
                        y_pred = y_pred.ravel()

                    mse = mean_squared_error(y_test, y_pred)

                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        joblib.dump(model, save_path)

                    return mse

                study.optimize(objective, n_trials=50)

            elapsed_time = time.time() - start_time

            # Load frozen model (NO RETRAIN)
            best_model = joblib.load(
                os.path.join(model_save_dir, f"{model_name}_{pruner_name}_BEST.pkl")
            )

            y_pred = best_model.predict(X_test)

            if model_name == 'TabNet':
                y_pred = y_pred.ravel()

            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            corr_coef = np.corrcoef(y_test, y_pred)[0, 1]


            predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

            best_scores[(model_name, pruner_name)] = {
                'best_score': mse,
                'best_params': study.best_params,
                'test_mse': mse,
                'test_rmse': rmse,
                'test_corr_coef': corr_coef,
                'pruner': pruner_name
            }

            timing_records.append({
                'Model': model_name,
                'Pruner': pruner_name,
                'Tuning_Time_Seconds': elapsed_time
            })

        # RMSE plots & Excel writing (UNCHANGED)
       # rmse_df = pd.DataFrame(rmse_trial_history)
       # rmse_df.insert(0, "Trial", np.arange(1, len(rmse_df) + 1))

       # with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a',
            # if_sheet_exists='replace') as writer:
            #rmse_df.to_excel(writer, sheet_name=f"RMSE_Trials_{model_name}", index=False)
        # ================= SAVE RMSE PLOT =================
        #plot_dir = os.path.dirname(excel_path)
       # plot_path = os.path.join(plot_dir, f"RMSE_Trials_{model_name}.png")

        #plt.figure(figsize=(10, 6))
        #for pruner_name, values in rmse_trial_history.items():
           # if len(values) > 0:   # <-- important safety check
               # plt.plot(values, label=pruner_name, linewidth=2)

        #plt.title(f"RMSE Variation Over Trials\n{model_name}")
        #plt.xlabel("Trial Number")
        #plt.ylabel("RMSE")
        #plt.legend(loc="center left", bbox_to_anchor=(1.02, 0.5))
        #plt.tight_layout()

        #plt.savefig(plot_path, dpi=100, bbox_inches="tight")
        #plt.close()

        # ================= INSERT PLOT INTO EXCEL =================
        #wb = load_workbook(excel_path)
        #ws = wb[f"RMSE_Trials_{model_name}"]

        #img = Image(plot_path)
        #img.anchor = "J2"
       # ws.add_image(img)

        #wb.save(excel_path)

    timing_df = pd.DataFrame(timing_records)

    with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a') as writer:
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)
        timing_df.to_excel(writer, sheet_name='Tuning_Time', index=False)

    return best_scores


best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/pile_load_gendy_data/HyperParameter_Tuning/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# [I 2026-03-07 18:24:35,457] A new study created in memory with name: no-name-5a9be35e-1e7e-481f-8949-fa90fa281dfc
# [I 2026-03-07 18:24:37,683] Trial 0 finished with value: 265.37311599390165 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:39,684] Trial 1 finished with value: 283.20802879439606 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:41,818] Trial 2 finished with value: 341.8041126507041 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:42,854] Trial 3 finished with value: 276.2334739832647 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:44,858] Trial 4 finished with value: 561.649902376208 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:48,684] Trial 5 finished with value: 379.55560310340707 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:49,242] Trial 6 finished with value: 554.8128482374113 and parameters: {'n_estimators': 200, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:49,862] Trial 7 finished with value: 564.223141172473 and parameters: {'n_estimators': 100, 'criterion': 'squared_error', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:51,618] Trial 8 finished with value: 574.5090927871747 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.3, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:52,480] Trial 9 finished with value: 546.2765628061416 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:54,125] Trial 10 finished with value: 553.4688596431204 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:55,226] Trial 11 finished with value: 272.4409685417509 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:55,560] Trial 12 finished with value: 580.4088089336273 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:56,623] Trial 13 finished with value: 311.3178765172505 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 0 with value: 265.37311599390165.
# [I 2026-03-07 18:24:59,401] Trial 14 finished with value: 186.80482825026485 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 14 with value: 186.80482825026485.
# [I 2026-03-07 18:25:01,453] Trial 15 finished with value: 186.35914251173068 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:03,396] Trial 16 finished with value: 188.4593578894392 and parameters: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:05,564] Trial 17 finished with value: 496.5766033429425 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:06,787] Trial 18 finished with value: 358.24555102640295 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:08,192] Trial 19 finished with value: 197.12592729958862 and parameters: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:11,327] Trial 20 finished with value: 700.7059316452076 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:13,577] Trial 21 finished with value: 292.4120447285992 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 15 with value: 186.35914251173068.
# [I 2026-03-07 18:25:14,611] Trial 22 finished with value: 225.78465272077844 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial
and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 41 with value: 172.75005753762386.
# [I 2026-03-07 18:27:01,498] Trial 45 finished with value: 170.63237236151866 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 45 with value: 170.63237236151866.
# [I 2026-03-07 18:27:01,877] Trial 46 finished with value: 170.63124260879067 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 46 with value: 170.63124260879067.
# [I 2026-03-07 18:27:02,195] Trial 47 finished with value: 261.65395495779836 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 46 with value: 170.63124260879067.
# [I 2026-03-07 18:27:02,548] Trial 48 finished with value: 170.63237236151863 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 46 with value: 170.63124260879067.
# [I 2026-03-07 18:27:02,889] Trial 49 finished with value: 170.63237236151863 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 46 with value: 170.63124260879067.
# [I 2026-03-07 18:27:02,987] A new study created in memory with name: no-name-a865bdbb-2c95-48a1-b827-896aa5c29dd7
# Running Optuna for Random Forest with PatientPruner...
# [I 2026-03-07 18:27:03,309] Trial 0 finished with value: 509.478347243646 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 509.478347243646.
# [I 2026-03-07 18:27:04,794] Trial 1 finished with value: 288.61052879867947 and parameters: {'n_estimators': 500, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 1 with value: 288.61052879867947.
# [I 2026-03-07 18:27:05,631] Trial 2 finished with value: 552.0543708411805 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 1 with value: 288.61052879867947.
# [I 2026-03-07 18:27:05,898] Trial 3 finished with value: 564.2210834187349 and parameters: {'n_estimators': 100, 'criterion': 'squared_error', 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 1 with value: 288.61052879867947.
# ...
# Training on CPU
# [I 2026-03-07 22:20:04,106] Trial 11 finished with value: 166.46329055354187 and parameters: {'n_estimators': 300, 'learning_rate': 0.05, 'max_leaves': 27, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 1 with value: 134.41623996336995.
# Training on CPU
# [I 2026-03-07 22:20:12,434] Trial 12 finished with value: 164.87728345285444 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 42, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'tree_correlation': 0.0, 'min_data_in_leaf': 20, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 1 with value: 134.41623996336995.
# Training on CPU
# [I 2026-03-07 22:20:24,917] Trial 13 finished with value: 135.68123474670898 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_leaves': 40, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 1 with value: 134.41623996336995.
# Training on CPU
# [I 2026-03-07 22:20:30,419] Trial 14 finished with value: 366.8089614920349 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'max_leaves': 35, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 20, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 1 with value: 134.41623996336995.
# Training on CPU
# [I 2026-03-07 22:20:40,523] Trial 15 finished with value: 129.68754281829936 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_leaves': 47, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:20:51,247] Trial 16 finished with value: 143.42923832869658 and parameters: {'n_estimators': 300, 'learning_rate': 0.05, 'max_leaves': 41, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:00,924] Trial 17 finished with value: 139.70309995639644 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_leaves': 57, 'min_split_gain': 1.0, 'reg_lambda': 0.1, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:09,312] Trial 18 finished with value: 150.57334830416053 and parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'max_leaves': 54, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:16,757] Trial 19 finished with value: 148.5022776344112 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_leaves': 44, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 1.0, 'tree_correlation': 0.1, 'min_data_in_leaf': 3, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:28,952] Trial 20 finished with value: 133.5580622274623 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 31, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:40,369] Trial 21 finished with value: 131.55035589518855 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 31, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 15 with value: 129.68754281829936.
# Training on CPU
# [I 2026-03-07 22:21:51,532] Trial 22 finished with value: 125.54137971636824 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 29, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 22 with value: 125.54137971636824.
# Training on CPU
# [I 2026-03-07 22:22:07,921] Trial 23 finished with value: 126.18686913593676 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 30, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 22 with value: 125.54137971636824.
# Training on CPU
# [I 2026-03-07 22:22:26,224] Trial 24 finished with value: 123.84654046312829 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 29, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 3, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 24 with value: 123.84654046312829.
# Training on CPU
# [I 2026-03-07 22:22:32,003] Trial 25 finished with value: 138.67992002198122 and parameters: {'n_estimators': 200, 'learning_rate': 0.15, 'max_leaves': 18, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 3, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 24 with value: 123.84654046312829.
# Training on CPU
# [I 2026-03-07 22:22:58,472] Trial 26 finished with value: 131.08491672893993 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 37, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 3, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 24 with value: 123.84654046312829.
# Training on CPU
# [I 2026-03-07 22:23:13,850] Trial 27 finished with value: 125.14693823726385 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 26, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 24 with value: 123.84654046312829.
# Training on CPU
# [I 2026-03-07 22:23:24,250] Trial 28 finished with value: 128.32315337158883 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 17, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 24 with value: 123.84654046312829.
# Training on CPU
# [I 2026-03-07 22:23:53,462] Trial 29 finished with value: 113.24039844619318 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 37, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:24:15,752] Trial 30 finished with value: 135.09905289340958 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 32, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 3, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:24:21,980] Trial 31 finished with value: 135.60797563234465 and parameters: {'n_estimators': 200, 'learning_rate': 0.15, 'max_leaves': 21, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:24:51,963] Trial 32 finished with value: 124.63193858837202 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 31, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:25:33,235] Trial 33 finished with value: 127.73946311458849 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 33, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 256, 'distribution': 'studentt'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:26:14,863] Trial 34 finished with value: 116.72992073133969 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 43, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 29 with value: 113.24039844619318.
# Training on CPU
# [I 2026-03-07 22:26:42,259] Trial 35 finished with value: 111.58732699524266 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 54, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 35 with value: 111.58732699524266.
# Training on CPU
# [I 2026-03-07 22:27:31,470] Trial 36 finished with value: 115.67050450037516 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 59, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 35 with value: 111.58732699524266.
# Training on CPU
# [I 2026-03-07 22:27:54,392] Trial 37 finished with value: 119.40610304266116 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 40, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'normal'}. Best is trial 35 with value: 111.58732699524266.
# Training on CPU
# [I 2026-03-07 22:28:45,225] Trial 38 finished with value: 161.73961387653551 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 46, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.9, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 35 with value: 111.58732699524266.
# Training on CPU
# [I 2026-03-07 22:28:53,798] Trial 39 finished with value: 160.1287431890983 and parameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_leaves': 56, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 256, 'distribution': 'studentt'}. Best is trial 35 with value: 111.58732699524266.
# Training on CPU
# [I 2026-03-07 22:29:44,561] Trial 40 finished with value: 105.48508904482442 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 58, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:30:31,895] Trial 41 finished with value: 122.45369601103782 and parameters: {'n_estimators': 500, 'learning_rate': 0.05, 'max_leaves': 58, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:31:00,373] Trial 42 finished with value: 111.58732699524266 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 63, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.1, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'studentt'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:31:33,993] Trial 43 finished with value: 110.45248096055018 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 62, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:32:09,405] Trial 44 finished with value: 110.45248096055018 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 54, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:32:42,685] Trial 45 finished with value: 110.45248096055018 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 50, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:33:33,647] Trial 46 finished with value: 127.40561449780365 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 63, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 3, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:33:57,779] Trial 47 finished with value: 125.64720882575685 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 46, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.5, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:34:01,303] Trial 48 finished with value: 174.1637372004129 and parameters: {'n_estimators': 100, 'learning_rate': 0.15, 'max_leaves': 52, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 40 with value: 105.48508904482442.
# Training on CPU
# [I 2026-03-07 22:34:14,062] Trial 49 finished with value: 108.93065093488997 and parameters: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 49, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 128, 'distribution': 'normal'}. Best is trial 40 with value: 105.48508904482442.

# %%
best_scores_autosampler
# Out:
# {('Random Forest', 'MedianPruner'): {'best_score': 152.98063120551464,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 152.98063120551464,
#   'test_rmse': 12.368533914959956,
#   'test_corr_coef': 0.9100717040625368,
#   'pruner': 'MedianPruner'},
#  ('Random Forest', 'NopPruner'): {'best_score': 170.63124260879067,
#   'best_params': {'n_estimators': 100,
#    'criterion': 'poisson',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 170.63124260879067,
#   'test_rmse': 13.062589429695425,
#   'test_corr_coef': 0.8943907434686084,
#   'pruner': 'NopPruner'},
#  ('Random Forest', 'PatientPruner'): {'best_score': 180.04588999142493,
#   'best_params': {'n_estimators': 100,
#    'criterion': 'poisson',
#    'max_depth': 10,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.5,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 180.04588999142493,
#   'test_rmse': 13.418117975015159,
#   'test_corr_coef': 0.8893904103704389,
#   'pruner': 'PatientPruner'},
#  ('Random Forest', 'PercentilePruner'): {'best_score': 154.16247953238616,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.1},
#   'test_mse': 154.16247953238616,
#   'test_rmse': 12.416218407082978,
#   'test_corr_coef': 0.9098826634121733,
#   'pruner': 'PercentilePruner'},
#  ('Random Forest',
#   'SuccessiveHalvingPruner'): {'best_score': 152.46010559118824, 'best_params': {'n_estimators': 700,
#    'criterion': 'friedman_mse',
#    'max_depth': None,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.05}, 'test_mse': 152.46010559118824, 'test_rmse': 12.347473652176312, 'test_corr_coef': 0.9101947022096951, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Random Forest', 'HyperbandPruner'): {'best_score': 163.0289258942997,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'poisson',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 163.0289258942997,
#   'test_rmse': 12.768278109999786,
#   'test_corr_coef': 0.9002897960107232,
#   'pruner': 'HyperbandPruner'},
#  ('Random Forest', 'ThresholdPruner'): {'best_score': 154.64840720467092,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'friedman_mse',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 154.64840720467092,
#   'test_rmse': 12.435771275022347,
#   'test_corr_coef': 0.9065053984224763,
#   'pruner': 'ThresholdPruner'},
#  ('Random Forest', 'WilcoxonPruner'): {'best_score': 158.28207318969893,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'squared_error',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.05},
#   'test_mse': 158.28207318969893,
#   'test_rmse': 12.581020355666663,
#   'test_corr_coef': 0.9052738863008764,
#   'pruner': 'WilcoxonPruner'},
#  ('Gradient Boosting', 'MedianPruner'): {'best_score': 106.82199342946828,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 200,
#    'subsample': 0.9,
#    'criterion': 'squared_error',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 106.82199342946828,
#   'test_rmse': 10.335472578913278,
#   'test_corr_coef': 0.9310344147012503,
#   'pruner': 'MedianPruner'},
#  ('Gradient Boosting', 'NopPruner'): {'best_score': 111.15668952779254,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.1,
#    'n_estimators': 200,
#    'subsample': 0.9,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 5,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 111.15668952779254,
#   'test_rmse': 10.543087286359368,
#   'test_corr_coef': 0.9270426649914485,
#   'pruner': 'NopPruner'},
#  ('Gradient Boosting', 'PatientPruner'): {'best_score': 89.02816733158211,
#   'best_params': {'loss': 'huber',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 89.02816733158211,
#   'test_rmse': 9.435473879545325,
#   'test_corr_coef': 0.9456205230324285,
#   'pruner': 'PatientPruner'},
#  ('Gradient Boosting', 'PercentilePruner'): {'best_score': 100.66262991393918,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.1,
#    'n_estimators': 700,
#    'subsample': 1.0,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 50,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 100.66262991393918,
#   'test_rmse': 10.033076791988547,
#   'test_corr_coef': 0.9342492651003499,
#   'pruner': 'PercentilePruner'},
#  ('Gradient Boosting',
#   'SuccessiveHalvingPruner'): {'best_score': 120.46198397430994, 'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 100,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001}, 'test_mse': 120.46198397430994, 'test_rmse': 10.975517480935007, 'test_corr_coef': 0.923499908135557, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Gradient Boosting', 'HyperbandPruner'): {'best_score': 109.53579015309792,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 500,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 50,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.01},
#   'test_mse': 109.53579015309792,
#   'test_rmse': 10.46593474817696,
#   'test_corr_coef': 0.9327627929002421,
#   'pruner': 'HyperbandPruner'},
#  ('Gradient Boosting', 'ThresholdPruner'): {'best_score': 107.86816836778692,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 500,
#    'subsample': 0.9,
#    'criterion': 'squared_error',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 107.86816836778692,
#   'test_rmse': 10.385960156277653,
#   'test_corr_coef': 0.9277543666060549,
#   'pruner': 'ThresholdPruner'},
#  ('Gradient Boosting', 'WilcoxonPruner'): {'best_score': 115.63069596852776,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.1,
#    'n_estimators': 200,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 115.63069596852776,
#   'test_rmse': 10.753171437698171,
#   'test_corr_coef': 0.9255816102420358,
#   'pruner': 'WilcoxonPruner'},
#  ('XGBoost', 'MedianPruner'): {'best_score': 100.58914887067544,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0.01,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 100.58914887067544,
#   'test_rmse': 10.029414183823272,
#   'test_corr_coef': 0.9359533194853996,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 89.61367880089917,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0.5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 89.61367880089917,
#   'test_rmse': 9.466450168933399,
#   'test_corr_coef': 0.9431313973448553,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 98.49578970490964,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 98.49578970490964,
#   'test_rmse': 9.924504506770583,
#   'test_corr_coef': 0.9365472186074788,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 67.93676050134304,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 67.93676050134304,
#   'test_rmse': 8.242375901482717,
#   'test_corr_coef': 0.9561296172273666,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 99.3361140760957,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.8,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 99.3361140760957,
#   'test_rmse': 9.966750427099884,
#   'test_corr_coef': 0.9389056880557962,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 86.68867330070917,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 86.68867330070917,
#   'test_rmse': 9.310675233338834,
#   'test_corr_coef': 0.9488970717669976,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 92.02039272806104,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0.1,
#    'subsample': 0.9,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 92.02039272806104,
#   'test_rmse': 9.592726032159005,
#   'test_corr_coef': 0.9432169166482989,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 93.85385734548784,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0.1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 93.85385734548784,
#   'test_rmse': 9.687820051254453,
#   'test_corr_coef': 0.9417304624183378,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 95.44911836418507,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'num_leaves': 15,
#    'max_depth': 7,
#    'min_child_samples': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'min_child_weight': 0.1,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 95.44911836418507,
#   'test_rmse': 9.769806465032206,
#   'test_corr_coef': 0.93682381557629,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 78.38037008965738,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'num_leaves': 63,
#    'max_depth': 7,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 78.38037008965738,
#   'test_rmse': 8.85326889288117,
#   'test_corr_coef': 0.9541227486219568,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 100.44210495654774,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'num_leaves': 15,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 100.44210495654774,
#   'test_rmse': 10.0220808695873,
#   'test_corr_coef': 0.933242701768733,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 101.63336303111387,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'num_leaves': 31,
#    'max_depth': 7,
#    'min_child_samples': 1,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 10,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 101.63336303111387,
#   'test_rmse': 10.081337363222891,
#   'test_corr_coef': 0.9322923768116579,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 97.56376537904843,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'num_leaves': 63,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 1.0,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 97.56376537904843,
#   'test_rmse': 9.877437186793365,
#   'test_corr_coef': 0.9334568585552251,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 108.72600408852692,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'num_leaves': 31,
#    'max_depth': -1,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 108.72600408852692,
#   'test_rmse': 10.427176227940473,
#   'test_corr_coef': 0.926544507181797,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 100.48601146382701,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 100.48601146382701,
#   'test_rmse': 10.024271118830885,
#   'test_corr_coef': 0.9336433334531059,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 88.65248921998764,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 88.65248921998764,
#   'test_rmse': 9.41554508353009,
#   'test_corr_coef': 0.9452888449153922,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 98.89133129858779,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 98.89133129858779,
#   'test_rmse': 9.944412063997941,
#   'test_corr_coef': 0.933729392135044,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 101.36751534760184,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0.1,
#    'reg_lambda': 1.0,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 101.36751534760184,
#   'test_rmse': 10.068143589937613,
#   'test_corr_coef': 0.9311295278444216,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 95.51459146564854,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': -1,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 1.0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 95.51459146564854,
#   'test_rmse': 9.773156678660612,
#   'test_corr_coef': 0.935810950039782,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 95.02584170675935,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 95.02584170675935,
#   'test_rmse': 9.748119906256763,
#   'test_corr_coef': 0.9367257738852067,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 103.04660969928004,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': -1,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0.5,
#    'reg_lambda': 1.0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 103.04660969928004,
#   'test_rmse': 10.151187600437696,
#   'test_corr_coef': 0.9294310296392595,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 93.31598269527979,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_depth': -1,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 93.31598269527979,
#   'test_rmse': 9.660019808223987,
#   'test_corr_coef': 0.9374326288527489,
#   'pruner': 'HyperbandPruner'},
#  ('GPBoost', 'ThresholdPruner'): {'best_score': 96.29461706369923,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 96.29461706369923,
#   'test_rmse': 9.812982067837444,
#   'test_corr_coef': 0.934807468291228,
#   'pruner': 'ThresholdPruner'},
#  ('GPBoost', 'WilcoxonPruner'): {'best_score': 102.18009827730634,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': -1,
#    'num_leaves': 31,
#    'min_child_samples': 10,
#    'subsample': 0.7,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 102.18009827730634,
#   'test_rmse': 10.108417199408933,
#   'test_corr_coef': 0.9314026791262863,
#   'pruner': 'WilcoxonPruner'},
#  ('CatBoost', 'MedianPruner'): {'best_score': 85.48272460888411,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.1,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 20,
#    'rsm': 0.6,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 85.48272460888411,
#   'test_rmse': 9.245686811096519,
#   'test_corr_coef': 0.9445059932077939,
#   'pruner': 'MedianPruner'},
#  ('CatBoost', 'NopPruner'): {'best_score': 93.36712377305112,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 6,
#    'l2_leaf_reg': 3,
#    'border_count': 128,
#    'min_data_in_leaf': 20,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 93.36712377305112,
#   'test_rmse': 9.662666493936916,
#   'test_corr_coef': 0.9413875272554717,
#   'pruner': 'NopPruner'},
#  ('CatBoost', 'PatientPruner'): {'best_score': 89.50072499631383,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 128,
#    'min_data_in_leaf': 10,
#    'rsm': 1.0,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 89.50072499631383,
#   'test_rmse': 9.46048228138047,
#   'test_corr_coef': 0.9462768805177888,
#   'pruner': 'PatientPruner'},
#  ('CatBoost', 'PercentilePruner'): {'best_score': 88.95178129138309,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 128,
#    'min_data_in_leaf': 1,
#    'rsm': 0.8,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 88.95178129138309,
#   'test_rmse': 9.431425199373798,
#   'test_corr_coef': 0.945133421527909,
#   'pruner': 'PercentilePruner'},
#  ('CatBoost', 'SuccessiveHalvingPruner'): {'best_score': 85.36080983400738,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 5,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 85.36080983400738,
#   'test_rmse': 9.239091396560994,
#   'test_corr_coef': 0.944589054411141,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('CatBoost', 'HyperbandPruner'): {'best_score': 89.78953847272699,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.05,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 128,
#    'min_data_in_leaf': 20,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 89.78953847272699,
#   'test_rmse': 9.475734191751423,
#   'test_corr_coef': 0.9446376921418882,
#   'pruner': 'HyperbandPruner'},
#  ('CatBoost', 'ThresholdPruner'): {'best_score': 88.95178129138309,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 128,
#    'min_data_in_leaf': 1,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 88.95178129138309,
#   'test_rmse': 9.431425199373798,
#   'test_corr_coef': 0.945133421527909,
#   'pruner': 'ThresholdPruner'},
#  ('CatBoost', 'WilcoxonPruner'): {'best_score': 85.36080983400738,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 64,
#    'min_data_in_leaf': 5,
#    'rsm': 0.6,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 85.36080983400738,
#   'test_rmse': 9.239091396560994,
#   'test_corr_coef': 0.944589054411141,
#   'pruner': 'WilcoxonPruner'},
#  ('NGBoost', 'MedianPruner'): {'best_score': 153.3856053332811,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 153.3856053332811,
#   'test_rmse': 12.384894239890832,
#   'test_corr_coef': 0.8930112337646037,
#   'pruner': 'MedianPruner'},
#  ('NGBoost', 'NopPruner'): {'best_score': 143.30218176515817,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 143.30218176515817,
#   'test_rmse': 11.970888929614132,
#   'test_corr_coef': 0.9007498276924898,
#   'pruner': 'NopPruner'},
#  ('NGBoost', 'PatientPruner'): {'best_score': 157.5719110469103,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 157.5719110469103,
#   'test_rmse': 12.552765075747665,
#   'test_corr_coef': 0.8882779345461344,
#   'pruner': 'PatientPruner'},
#  ('NGBoost', 'PercentilePruner'): {'best_score': 159.10355471401047,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 159.10355471401047,
#   'test_rmse': 12.613625756062785,
#   'test_corr_coef': 0.8887176533138197,
#   'pruner': 'PercentilePruner'},
#  ('NGBoost', 'SuccessiveHalvingPruner'): {'best_score': 151.44908811890718,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 151.44908811890718,
#   'test_rmse': 12.306465297513627,
#   'test_corr_coef': 0.8942223224428472,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('NGBoost', 'HyperbandPruner'): {'best_score': 145.81711936793175,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 145.81711936793175,
#   'test_rmse': 12.07547594788428,
#   'test_corr_coef': 0.8990006764687222,
#   'pruner': 'HyperbandPruner'},
#  ('NGBoost', 'ThresholdPruner'): {'best_score': 152.87737506561598,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.5,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 152.87737506561598,
#   'test_rmse': 12.364359064084802,
#   'test_corr_coef': 0.8947260671053722,
#   'pruner': 'ThresholdPruner'},
#  ('NGBoost', 'WilcoxonPruner'): {'best_score': 155.76578578406654,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 1.0,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 155.76578578406654,
#   'test_rmse': 12.480616402408439,
#   'test_corr_coef': 0.8945010680208828,
#   'pruner': 'WilcoxonPruner'},
#  ('TabNet', 'MedianPruner'): {'best_score': 67.56506779356722,
#   'best_params': {'n_d': 32,
#    'n_a': 8,
#    'n_steps': 3,
#    'gamma': 2.0,
#    'lambda_sparse': 0.001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'sparsemax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 67.56506779356722,
#   'test_rmse': 8.21979730854522,
#   'test_corr_coef': 0.9530052734492968,
#   'pruner': 'MedianPruner'},
#  ('TabNet', 'NopPruner'): {'best_score': 76.08969444498896,
#   'best_params': {'n_d': 64,
#    'n_a': 8,
#    'n_steps': 3,
#    'gamma': 1.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'sparsemax',
#    'n_shared': 1,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 76.08969444498896,
#   'test_rmse': 8.722940699385097,
#   'test_corr_coef': 0.9539981359400319,
#   'pruner': 'NopPruner'},
#  ('TabNet', 'PatientPruner'): {'best_score': 51.715715833103495,
#   'best_params': {'n_d': 64,
#    'n_a': 16,
#    'n_steps': 10,
#    'gamma': 1.0,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 3,
#    'n_independent': 2,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 51.715715833103495,
#   'test_rmse': 7.191363975846549,
#   'test_corr_coef': 0.9656865213398506,
#   'pruner': 'PatientPruner'},
#  ('TabNet', 'PercentilePruner'): {'best_score': 71.63011611867866,
#   'best_params': {'n_d': 64,
#    'n_a': 64,
#    'n_steps': 10,
#    'gamma': 1.0,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 2,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 71.63011611867866,
#   'test_rmse': 8.463457692850993,
#   'test_corr_coef': 0.9654969292739963,
#   'pruner': 'PercentilePruner'},
#  ('TabNet', 'SuccessiveHalvingPruner'): {'best_score': 82.00418994914077,
#   'best_params': {'n_d': 64,
#    'n_a': 16,
#    'n_steps': 3,
#    'gamma': 2.0,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'sparsemax',
#    'n_shared': 2,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 82.00418994914077,
#   'test_rmse': 9.055616486421052,
#   'test_corr_coef': 0.9437403007013775,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('TabNet', 'HyperbandPruner'): {'best_score': 61.70944877314963,
#   'best_params': {'n_d': 8,
#    'n_a': 16,
#    'n_steps': 3,
#    'gamma': 1.5,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 2,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 61.70944877314963,
#   'test_rmse': 7.855536186228769,
#   'test_corr_coef': 0.9585631287990138,
#   'pruner': 'HyperbandPruner'},
#  ('TabNet', 'ThresholdPruner'): {'best_score': 75.58697579720257,
#   'best_params': {'n_d': 64,
#    'n_a': 64,
#    'n_steps': 10,
#    'gamma': 1.0,
#    'lambda_sparse': 0.01,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 2,
#    'n_independent': 1,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 75.58697579720257,
#   'test_rmse': 8.694077052637764,
#   'test_corr_coef': 0.9758601351677328,
#   'pruner': 'ThresholdPruner'},
#  ('TabNet', 'WilcoxonPruner'): {'best_score': 71.4337647373294,
#   'best_params': {'n_d': 16,
#    'n_a': 64,
#    'n_steps': 5,
#    'gamma': 1.3,
#    'lambda_sparse': 0.0001,
#    'optimizer_params': {'lr': 0.02},
#    'mask_type': 'entmax',
#    'n_shared': 1,
#    'n_independent': 2,
#    'scheduler_params': {'step_size': 10, 'gamma': 0.9},
#    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#    'seed': 42,
#    'verbose': 0},
#   'test_mse': 71.4337647373294,
#   'test_rmse': 8.451849781990296,
#   'test_corr_coef': 0.9505375759724721,
#   'pruner': 'WilcoxonPruner'},
#  ('HistGradientBoosting', 'MedianPruner'): {'best_score': 129.3442580892259,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 300,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 63,
#    'l2_regularization': 0.5,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 129.3442580892259,
#   'test_rmse': 11.372961711411232,
#   'test_corr_coef': 0.9110563465189973,
#   'pruner': 'MedianPruner'},
#  ('HistGradientBoosting', 'NopPruner'): {'best_score': 128.84698844088038,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 300,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 128.84698844088038,
#   'test_rmse': 11.351078734678937,
#   'test_corr_coef': 0.9126867001605148,
#   'pruner': 'NopPruner'},
#  ('HistGradientBoosting', 'PatientPruner'): {'best_score': 118.10639347146959,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.1,
#    'max_bins': 64,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 118.10639347146959,
#   'test_rmse': 10.867676544297295,
#   'test_corr_coef': 0.9232102276248901,
#   'pruner': 'PatientPruner'},
#  ('HistGradientBoosting',
#   'PercentilePruner'): {'best_score': 118.33165303465466, 'best_params': {'learning_rate': 0.1,
#    'max_iter': 500,
#    'max_depth': 7,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 1.0,
#    'max_bins': 64,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 118.33165303465466, 'test_rmse': 10.878035348106508, 'test_corr_coef': 0.9214138007846934, 'pruner': 'PercentilePruner'},
#  ('HistGradientBoosting',
#   'SuccessiveHalvingPruner'): {'best_score': 120.04036901152315, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 500,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 120.04036901152315, 'test_rmse': 10.956293580017064, 'test_corr_coef': 0.9202582418957181, 'pruner': 'SuccessiveHalvingPruner'},
#  ('HistGradientBoosting',
#   'HyperbandPruner'): {'best_score': 116.79271602948637, 'best_params': {'learning_rate': 0.1,
#    'max_iter': 500,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 1.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 116.79271602948637, 'test_rmse': 10.8070678738262, 'test_corr_coef': 0.9225001141872002, 'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting',
#   'ThresholdPruner'): {'best_score': 114.40748198147847, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 500,
#    'max_depth': 5,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 114.40748198147847, 'test_rmse': 10.696143322781277, 'test_corr_coef': 0.9255663426415169, 'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 117.98955148062424,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 300,
#    'max_depth': 7,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': None,
#    'l2_regularization': 1.0,
#    'max_bins': 64,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 117.98955148062424,
#   'test_rmse': 10.8622995484669,
#   'test_corr_coef': 0.9224400475682029,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 110.06646235121923,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 59,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 110.06646235121923,
#   'test_rmse': 10.491256471520426,
#   'test_corr_coef': 0.9238145638885917,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 116.36760716412837,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 54,
#    'min_split_gain': 0.5,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 116.36760716412837,
#   'test_rmse': 10.787381849370512,
#   'test_corr_coef': 0.9212230066839205,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 120.43814576742204,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'max_leaves': 19,
#    'min_split_gain': 0.1,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 120.43814576742204,
#   'test_rmse': 10.97443145531567,
#   'test_corr_coef': 0.9174495811585923,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 105.28414366018494,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 15,
#    'min_split_gain': 0.1,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 105.28414366018494,
#   'test_rmse': 10.260806189583006,
#   'test_corr_coef': 0.9302272067031147,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 109.29949887489617,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_leaves': 56,
#    'min_split_gain': 0.5,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'normal'},
#   'test_mse': 109.29949887489617,
#   'test_rmse': 10.454640064339669,
#   'test_corr_coef': 0.9255118931278087,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 110.77295523525386,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 34,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 110.77295523525386,
#   'test_rmse': 10.52487316955667,
#   'test_corr_coef': 0.9231205172720397,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 111.64254560217586,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_leaves': 55,
#    'min_split_gain': 0.1,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 111.64254560217586,
#   'test_rmse': 10.566103614964973,
#   'test_corr_coef': 0.9236377603457087,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 105.48508904482442,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 58,
#    'min_split_gain': 0.0,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 105.48508904482442,
#   'test_rmse': 10.270593412496886,
#   'test_corr_coef': 0.9287649006989753,
#   'pruner': 'WilcoxonPruner'}}

# %% [markdown]
# # **Best Model Analysis**

# %%
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'TabNet': TabNetRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        elif model_name == 'TabNet':
            model = model_class(**best_params)
            model.fit(X_train, y_train.reshape(-1, 1))
            predictions = model.predict(X_test)
            predictions = predictions.ravel()
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual Y_Label")
        plt.ylabel("Predicted Y_Label")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        plt.savefig(plot_path)
        plt.close()

    # ✅ NEW OUTPUT DIRECTORY
    output_dir = "./drive/MyDrive/pile_load_gendy_data/HyperParameter_Tuning/"
    os.makedirs(output_dir, exist_ok=True)

    output_excel_path = os.path.join(
        output_dir,
        os.path.basename(file_path).replace('.csv', '_results.xlsx')
    )

    # Save predictions and plots to Excel
    with pd.ExcelWriter(output_excel_path, engine='xlsxwriter') as writer:
        # Write data to Excel
        df.to_excel(writer, sheet_name='Data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            short_model_name = ''.join([word[0] for word in model_name.split()])
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        os.remove(f'temp_plot_{model_name}.png')

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/pile_load_gendy_data/Data/test.csv")
# Out:
# 0:	learn: 22.7208169	total: 647us	remaining: 647ms
# 1:	learn: 21.6646146	total: 1.08ms	remaining: 539ms
# 2:	learn: 20.3447617	total: 1.88ms	remaining: 626ms
# 3:	learn: 19.2519102	total: 2.91ms	remaining: 724ms
# 4:	learn: 18.0645490	total: 3.85ms	remaining: 766ms
# 5:	learn: 17.3239387	total: 4.38ms	remaining: 725ms
# 6:	learn: 16.2505176	total: 5.57ms	remaining: 790ms
# 7:	learn: 15.3201681	total: 6.32ms	remaining: 784ms
# 8:	learn: 14.3972520	total: 6.96ms	remaining: 767ms
# 9:	learn: 13.6590869	total: 8.07ms	remaining: 799ms
# 891:	learn: 1.1021655	total: 1.37s	remaining: 166ms
# 892:	learn: 1.1021650	total: 1.37s	remaining: 165ms
# 893:	learn: 1.1021641	total: 1.38s	remaining: 163ms
# 894:	learn: 1.1021637	total: 1.38s	remaining: 162ms
# 895:	learn: 1.1021632	total: 1.38s	remaining: 160ms
# 896:	learn: 1.1021626	total: 1.38s	remaining: 159ms
# 897:	learn: 1.1021623	total: 1.38s	remaining: 157ms
# 898:	learn: 1.1021619	total: 1.38s	remaining: 156ms
# 899:	learn: 1.1021613	total: 1.39s	remaining: 154ms
# 900:	learn: 1.1021611	total: 1.39s	remaining: 153ms
# 901:	learn: 1.1021609	total: 1.39s	remaining: 151ms
# 902:	learn: 1.1021599	total: 1.39s	remaining: 150ms
# 903:	learn: 1.1021595	total: 1.4s	remaining: 148ms
# 904:	learn: 1.1021589	total: 1.4s	remaining: 147ms
# 905:	learn: 1.1021583	total: 1.4s	remaining: 145ms
# 906:	learn: 1.1021579	total: 1.4s	remaining: 144ms
# 907:	learn: 1.1021572	total: 1.4s	remaining: 142ms
# 908:	learn: 1.1021569	total: 1.41s	remaining: 141ms
# 909:	learn: 1.1021564	total: 1.41s	remaining: 139ms
# 910:	learn: 1.1021557	total: 1.41s	remaining: 138ms
# 911:	learn: 1.1021555	total: 1.41s	remaining: 136ms
# 912:	learn: 1.1021553	total: 1.42s	remaining: 135ms
# 913:	learn: 1.1021547	total: 1.42s	remaining: 133ms
# 914:	learn: 1.1021543	total: 1.42s	remaining: 132ms
# 915:	learn: 1.1021540	total: 1.42s	remaining: 130ms
# 916:	learn: 1.1021535	total: 1.42s	remaining: 129ms
# 917:	learn: 1.1021533	total: 1.43s	remaining: 127ms
# 918:	learn: 1.1021527	total: 1.43s	remaining: 126ms
# 919:	learn: 1.1021522	total: 1.43s	remaining: 124ms
# 920:	learn: 1.1021518	total: 1.43s	remaining: 123ms
# 921:	learn: 1.1021515	total: 1.43s	remaining: 121ms
# 922:	learn: 1.1021512	total: 1.43s	remaining: 120ms
# ...
# Estimator 100/500, Train metric: 4.2579
# Estimator 101/500, Train metric: 4.2485
# Estimator 102/500, Train metric: 4.2362
# Estimator 103/500, Train metric: 4.2132
# Estimator 104/500, Train metric: 4.1884
# Estimator 105/500, Train metric: 4.1733
# Estimator 106/500, Train metric: 4.1630
# Estimator 107/500, Train metric: 4.1447
# Estimator 108/500, Train metric: 4.0921
# Estimator 109/500, Train metric: 4.0749
# Estimator 110/500, Train metric: 4.0523
# Estimator 111/500, Train metric: 4.0308
# Estimator 112/500, Train metric: 4.0152
# Estimator 113/500, Train metric: 4.0034
# Estimator 114/500, Train metric: 3.9792
# Estimator 115/500, Train metric: 3.9407
# Estimator 116/500, Train metric: 3.9286
# Estimator 117/500, Train metric: 3.9152
# Estimator 118/500, Train metric: 3.8771
# Estimator 119/500, Train metric: 3.8649
# Estimator 120/500, Train metric: 3.8519
# Estimator 121/500, Train metric: 3.8431
# Estimator 122/500, Train metric: 3.8351
# Estimator 123/500, Train metric: 3.8136
# Estimator 124/500, Train metric: 3.8019
# Estimator 125/500, Train metric: 3.7934
# Estimator 126/500, Train metric: 3.7785
# Estimator 127/500, Train metric: 3.7599
# Estimator 128/500, Train metric: 3.7451
# Estimator 129/500, Train metric: 3.7048
# Estimator 130/500, Train metric: 3.6879
# Estimator 131/500, Train metric: 3.6756
# Estimator 132/500, Train metric: 3.6529
# Estimator 133/500, Train metric: 3.6245
# Estimator 134/500, Train metric: 3.6078
# Estimator 135/500, Train metric: 3.5948
# Estimator 136/500, Train metric: 3.5647
# Estimator 137/500, Train metric: 3.5563
# Estimator 138/500, Train metric: 3.5424
# Estimator 139/500, Train metric: 3.5315
# Estimator 140/500, Train metric: 3.5080
# Estimator 141/500, Train metric: 3.5000
# Estimator 142/500, Train metric: 3.4927
# Estimator 143/500, Train metric: 3.4792
# Estimator 144/500, Train metric: 3.4671
# Estimator 145/500, Train metric: 3.4573
# Estimator 146/500, Train metric: 3.4399
# Estimator 147/500, Train metric: 3.4322
# Estimator 148/500, Train metric: 3.4159
# Estimator 149/500, Train metric: 3.4061
# Estimator 150/500, Train metric: 3.3818
# Estimator 151/500, Train metric: 3.3671
# Estimator 152/500, Train metric: 3.3603
# Estimator 153/500, Train metric: 3.3439
# Estimator 154/500, Train metric: 3.3330
# Estimator 155/500, Train metric: 3.3251
# Estimator 156/500, Train metric: 3.3132
# Estimator 157/500, Train metric: 3.3006
# Estimator 158/500, Train metric: 3.2921
# Estimator 159/500, Train metric: 3.2807
# Estimator 160/500, Train metric: 3.2720
# Estimator 161/500, Train metric: 3.2666
# Estimator 162/500, Train metric: 3.2578
# Estimator 163/500, Train metric: 3.2477
# Estimator 164/500, Train metric: 3.2335
# Estimator 165/500, Train metric: 3.2295
# Estimator 166/500, Train metric: 3.2211
# Estimator 167/500, Train metric: 3.2094
# Estimator 168/500, Train metric: 3.1949
# Estimator 169/500, Train metric: 3.1748
# Estimator 170/500, Train metric: 3.1678
# Estimator 171/500, Train metric: 3.1447
# Estimator 172/500, Train metric: 3.1279
# Estimator 173/500, Train metric: 3.1179
# Estimator 174/500, Train metric: 3.0928
# Estimator 175/500, Train metric: 3.0820
# Estimator 176/500, Train metric: 3.0758
# Estimator 177/500, Train metric: 3.0639
# Estimator 178/500, Train metric: 3.0544
# Estimator 179/500, Train metric: 3.0510
# Estimator 180/500, Train metric: 3.0436
# Estimator 181/500, Train metric: 3.0341
# Estimator 182/500, Train metric: 3.0253
# Estimator 183/500, Train metric: 3.0104
# Estimator 184/500, Train metric: 2.9987
# Estimator 185/500, Train metric: 2.9940
# Estimator 186/500, Train metric: 2.9788
# Estimator 187/500, Train metric: 2.9650
# Estimator 188/500, Train metric: 2.9514
# Estimator 189/500, Train metric: 2.9405
# Estimator 190/500, Train metric: 2.9321
# Estimator 191/500, Train metric: 2.9261
# Estimator 192/500, Train metric: 2.9201
# Estimator 193/500, Train metric: 2.9135
# Estimator 194/500, Train metric: 2.9088
# Estimator 195/500, Train metric: 2.8975
# Estimator 196/500, Train metric: 2.8881
# Estimator 197/500, Train metric: 2.8742
# Estimator 198/500, Train metric: 2.8684
# Estimator 199/500, Train metric: 2.8613
# Estimator 200/500, Train metric: 2.8555
# Estimator 201/500, Train metric: 2.8489
# Estimator 202/500, Train metric: 2.8420
# Estimator 203/500, Train metric: 2.8275
# Estimator 204/500, Train metric: 2.8217
# Estimator 205/500, Train metric: 2.8150
# Estimator 206/500, Train metric: 2.8103
# Estimator 207/500, Train metric: 2.8058
# Estimator 208/500, Train metric: 2.7999
# Estimator 209/500, Train metric: 2.7931
# Estimator 210/500, Train metric: 2.7872
# Estimator 211/500, Train metric: 2.7743
# Estimator 212/500, Train metric: 2.7707
# Estimator 213/500, Train metric: 2.7654
# Estimator 214/500, Train metric: 2.7556
# Estimator 215/500, Train metric: 2.7483
# Estimator 216/500, Train metric: 2.7382
# Estimator 217/500, Train metric: 2.7299
# Estimator 218/500, Train metric: 2.7269
# Estimator 219/500, Train metric: 2.7226
# Estimator 220/500, Train metric: 2.7129
# Estimator 221/500, Train metric: 2.7048
# Estimator 222/500, Train metric: 2.7002
# Estimator 223/500, Train metric: 2.6941
# Estimator 224/500, Train metric: 2.6897
# Estimator 225/500, Train metric: 2.6838
# Estimator 226/500, Train metric: 2.6791
# Estimator 227/500, Train metric: 2.6712
# Estimator 228/500, Train metric: 2.6630
# Estimator 229/500, Train metric: 2.6604
# Estimator 230/500, Train metric: 2.6548
# Estimator 231/500, Train metric: 2.6494
# Estimator 232/500, Train metric: 2.6421
# Estimator 233/500, Train metric: 2.6338
# Estimator 234/500, Train metric: 2.6278
# Estimator 235/500, Train metric: 2.6182
# Estimator 236/500, Train metric: 2.6062
# Estimator 237/500, Train metric: 2.6020
# Estimator 238/500, Train metric: 2.5936
# Estimator 239/500, Train metric: 2.5872
# Estimator 240/500, Train metric: 2.5800
# Estimator 241/500, Train metric: 2.5720
# Estimator 242/500, Train metric: 2.5673
# Estimator 243/500, Train metric: 2.5595
# Estimator 244/500, Train metric: 2.5574
# Estimator 245/500, Train metric: 2.5481
# Estimator 246/500, Train metric: 2.5404
# Estimator 247/500, Train metric: 2.5359
# Estimator 248/500, Train metric: 2.5319
# Estimator 249/500, Train metric: 2.5189
# Estimator 250/500, Train metric: 2.5146
# Estimator 251/500, Train metric: 2.5099
# Estimator 252/500, Train metric: 2.5044
# Estimator 253/500, Train metric: 2.4956
# Estimator 254/500, Train metric: 2.4889
# Estimator 255/500, Train metric: 2.4810
# Estimator 256/500, Train metric: 2.4780
# Estimator 257/500, Train metric: 2.4701
# Estimator 258/500, Train metric: 2.4647
# Estimator 259/500, Train metric: 2.4624
# Estimator 260/500, Train metric: 2.4568
# Estimator 261/500, Train metric: 2.4536
# Estimator 262/500, Train metric: 2.4497
# Estimator 263/500, Train metric: 2.4450
# Estimator 264/500, Train metric: 2.4385
# Estimator 265/500, Train metric: 2.4325
# Estimator 266/500, Train metric: 2.4276
# Estimator 267/500, Train metric: 2.4244
# Estimator 268/500, Train metric: 2.4217
# Estimator 269/500, Train metric: 2.4175
# Estimator 270/500, Train metric: 2.4112
# Estimator 271/500, Train metric: 2.4084
# Estimator 272/500, Train metric: 2.4042
# Estimator 273/500, Train metric: 2.4012
# Estimator 274/500, Train metric: 2.3943
# Estimator 275/500, Train metric: 2.3896
# Estimator 276/500, Train metric: 2.3828
# Estimator 277/500, Train metric: 2.3756
# Estimator 278/500, Train metric: 2.3641
# Estimator 279/500, Train metric: 2.3589
# Estimator 280/500, Train metric: 2.3536
# Estimator 281/500, Train metric: 2.3477
# Estimator 282/500, Train metric: 2.3419
# Estimator 283/500, Train metric: 2.3369
# Estimator 284/500, Train metric: 2.3323
# Estimator 285/500, Train metric: 2.3221
# Estimator 286/500, Train metric: 2.3148
# Estimator 287/500, Train metric: 2.3123
# Estimator 288/500, Train metric: 2.3078
# Estimator 289/500, Train metric: 2.3046
# Estimator 290/500, Train metric: 2.2986
# Estimator 291/500, Train metric: 2.2915
# Estimator 292/500, Train metric: 2.2866
# Estimator 293/500, Train metric: 2.2860
# Estimator 294/500, Train metric: 2.2816
# Estimator 295/500, Train metric: 2.2772
# Estimator 296/500, Train metric: 2.2706
# Estimator 297/500, Train metric: 2.2680
# Estimator 298/500, Train metric: 2.2671
# Estimator 299/500, Train metric: 2.2644
# Estimator 300/500, Train metric: 2.2600
# Estimator 301/500, Train metric: 2.2550
# Estimator 302/500, Train metric: 2.2509
# Estimator 303/500, Train metric: 2.2483
# Estimator 304/500, Train metric: 2.2465
# Estimator 305/500, Train metric: 2.2423
# Estimator 306/500, Train metric: 2.2364
# Estimator 307/500, Train metric: 2.2321
# Estimator 308/500, Train metric: 2.2293
# Estimator 309/500, Train metric: 2.2249
# Estimator 310/500, Train metric: 2.2213
# Estimator 311/500, Train metric: 2.2178
# Estimator 312/500, Train metric: 2.2160
# Estimator 313/500, Train metric: 2.2080
# Estimator 314/500, Train metric: 2.1977
# Estimator 315/500, Train metric: 2.1909
# Estimator 316/500, Train metric: 2.1879
# Estimator 317/500, Train metric: 2.1860
# Estimator 318/500, Train metric: 2.1829
# Estimator 319/500, Train metric: 2.1796
# Estimator 320/500, Train metric: 2.1768
# Estimator 321/500, Train metric: 2.1741
# Estimator 322/500, Train metric: 2.1696
# Estimator 323/500, Train metric: 2.1668
# Estimator 324/500, Train metric: 2.1623
# Estimator 325/500, Train metric: 2.1549
# Estimator 326/500, Train metric: 2.1527
# Estimator 327/500, Train metric: 2.1517
# Estimator 328/500, Train metric: 2.1474
# Estimator 329/500, Train metric: 2.1458
# Estimator 330/500, Train metric: 2.1442
# Estimator 331/500, Train metric: 2.1423
# Estimator 332/500, Train metric: 2.1393
# Estimator 333/500, Train metric: 2.1333
# Estimator 334/500, Train metric: 2.1293
# Estimator 335/500, Train metric: 2.1264
# Estimator 336/500, Train metric: 2.1239
# Estimator 337/500, Train metric: 2.1204
# Estimator 338/500, Train metric: 2.1173
# Estimator 339/500, Train metric: 2.1142
# Estimator 340/500, Train metric: 2.1101
# Estimator 341/500, Train metric: 2.1076
# Estimator 342/500, Train metric: 2.1015
# Estimator 343/500, Train metric: 2.0975
# Estimator 344/500, Train metric: 2.0948
# Estimator 345/500, Train metric: 2.0920
# Estimator 346/500, Train metric: 2.0891
# Estimator 347/500, Train metric: 2.0846
# Estimator 348/500, Train metric: 2.0833
# Estimator 349/500, Train metric: 2.0770
# Estimator 350/500, Train metric: 2.0756
# Estimator 351/500, Train metric: 2.0717
# Estimator 352/500, Train metric: 2.0692
# Estimator 353/500, Train metric: 2.0664
# Estimator 354/500, Train metric: 2.0644
# Estimator 355/500, Train metric: 2.0620
# Estimator 356/500, Train metric: 2.0564
# Estimator 357/500, Train metric: 2.0529
# Estimator 358/500, Train metric: 2.0432
# Estimator 359/500, Train metric: 2.0359
# Estimator 360/500, Train metric: 2.0328
# Estimator 361/500, Train metric: 2.0299
# Estimator 362/500, Train metric: 2.0279
# Estimator 363/500, Train metric: 2.0263
# Estimator 364/500, Train metric: 2.0238
# Estimator 365/500, Train metric: 2.0203
# Estimator 366/500, Train metric: 2.0167
# Estimator 367/500, Train metric: 2.0138
# Estimator 368/500, Train metric: 2.0081
# Estimator 369/500, Train metric: 2.0064
# Estimator 370/500, Train metric: 2.0037
# Estimator 371/500, Train metric: 1.9992
# Estimator 372/500, Train metric: 1.9978
# Estimator 373/500, Train metric: 1.9951
# Estimator 374/500, Train metric: 1.9934
# Estimator 375/500, Train metric: 1.9927
# Estimator 376/500, Train metric: 1.9838
# Estimator 377/500, Train metric: 1.9813
# Estimator 378/500, Train metric: 1.9765
# Estimator 379/500, Train metric: 1.9740
# Estimator 380/500, Train metric: 1.9715
# Estimator 381/500, Train metric: 1.9684
# Estimator 382/500, Train metric: 1.9658
# Estimator 383/500, Train metric: 1.9626
# Estimator 384/500, Train metric: 1.9560
# Estimator 385/500, Train metric: 1.9538
# Estimator 386/500, Train metric: 1.9494
# Estimator 387/500, Train metric: 1.9450
# Estimator 388/500, Train metric: 1.9424
# Estimator 389/500, Train metric: 1.9360
# Estimator 390/500, Train metric: 1.9336
# Estimator 391/500, Train metric: 1.9277
# Estimator 392/500, Train metric: 1.9248
# Estimator 393/500, Train metric: 1.9224
# Estimator 394/500, Train metric: 1.9206
# Estimator 395/500, Train metric: 1.9193
# Estimator 396/500, Train metric: 1.9167
# Estimator 397/500, Train metric: 1.9160
# Estimator 398/500, Train metric: 1.9094
# Estimator 399/500, Train metric: 1.9071
# Estimator 400/500, Train metric: 1.9037
# Estimator 401/500, Train metric: 1.9013
# Estimator 402/500, Train metric: 1.8992
# Estimator 403/500, Train metric: 1.8980
# Estimator 404/500, Train metric: 1.8957
# Estimator 405/500, Train metric: 1.8936
# Estimator 406/500, Train metric: 1.8919
# Estimator 407/500, Train metric: 1.8902
# Estimator 408/500, Train metric: 1.8866
# Estimator 409/500, Train metric: 1.8834
# Estimator 410/500, Train metric: 1.8809
# Estimator 411/500, Train metric: 1.8794
# Estimator 412/500, Train metric: 1.8764
# Estimator 413/500, Train metric: 1.8738
# Estimator 414/500, Train metric: 1.8698
# Estimator 415/500, Train metric: 1.8677
# Estimator 416/500, Train metric: 1.8650
# Estimator 417/500, Train metric: 1.8637
# Estimator 418/500, Train metric: 1.8627
# Estimator 419/500, Train metric: 1.8589
# Estimator 420/500, Train metric: 1.8541
# Estimator 421/500, Train metric: 1.8533
# Estimator 422/500, Train metric: 1.8519
# Estimator 423/500, Train metric: 1.8496
# Estimator 424/500, Train metric: 1.8486
# Estimator 425/500, Train metric: 1.8475
# Estimator 426/500, Train metric: 1.8455
# Estimator 427/500, Train metric: 1.8421
# Estimator 428/500, Train metric: 1.8393
# Estimator 429/500, Train metric: 1.8366
# Estimator 430/500, Train metric: 1.8347
# Estimator 431/500, Train metric: 1.8327
# Estimator 432/500, Train metric: 1.8308
# Estimator 433/500, Train metric: 1.8287
# Estimator 434/500, Train metric: 1.8247
# Estimator 435/500, Train metric: 1.8223
# Estimator 436/500, Train metric: 1.8168
# Estimator 437/500, Train metric: 1.8149
# Estimator 438/500, Train metric: 1.8135
# Estimator 439/500, Train metric: 1.8121
# Estimator 440/500, Train metric: 1.8100
# Estimator 441/500, Train metric: 1.8079
# Estimator 442/500, Train metric: 1.8059
# Estimator 443/500, Train metric: 1.8056
# Estimator 444/500, Train metric: 1.8044
# Estimator 445/500, Train metric: 1.8041
# Estimator 446/500, Train metric: 1.8012
# Estimator 447/500, Train metric: 1.7967
# Estimator 448/500, Train metric: 1.7957
# Estimator 449/500, Train metric: 1.7925
# Estimator 450/500, Train metric: 1.7911
# Estimator 451/500, Train metric: 1.7887
# Estimator 452/500, Train metric: 1.7872
# Estimator 453/500, Train metric: 1.7838
# Estimator 454/500, Train metric: 1.7820
# Estimator 455/500, Train metric: 1.7805
# Estimator 456/500, Train metric: 1.7787
# Estimator 457/500, Train metric: 1.7775
# Estimator 458/500, Train metric: 1.7752
# Estimator 459/500, Train metric: 1.7740
# Estimator 460/500, Train metric: 1.7704
# Estimator 461/500, Train metric: 1.7690
# Estimator 462/500, Train metric: 1.7686
# Estimator 463/500, Train metric: 1.7662
# Estimator 464/500, Train metric: 1.7633
# Estimator 465/500, Train metric: 1.7617
# Estimator 466/500, Train metric: 1.7598
# Estimator 467/500, Train metric: 1.7583
# Estimator 468/500, Train metric: 1.7581
# Estimator 469/500, Train metric: 1.7566
# Estimator 470/500, Train metric: 1.7550
# Estimator 471/500, Train metric: 1.7545
# Estimator 472/500, Train metric: 1.7526
# Estimator 473/500, Train metric: 1.7501
# Estimator 474/500, Train metric: 1.7466
# Estimator 475/500, Train metric: 1.7446
# Estimator 476/500, Train metric: 1.7435
# Estimator 477/500, Train metric: 1.7424
# Estimator 478/500, Train metric: 1.7372
# Estimator 479/500, Train metric: 1.7350
# Estimator 480/500, Train metric: 1.7296
# Estimator 481/500, Train metric: 1.7264
# Estimator 482/500, Train metric: 1.7253
# Estimator 483/500, Train metric: 1.7245
# Estimator 484/500, Train metric: 1.7181
# Estimator 485/500, Train metric: 1.7164
# Estimator 486/500, Train metric: 1.7149
# Estimator 487/500, Train metric: 1.7110
# Estimator 488/500, Train metric: 1.7099
# Estimator 489/500, Train metric: 1.7087
# Estimator 490/500, Train metric: 1.7080
# Estimator 491/500, Train metric: 1.7056
# Estimator 492/500, Train metric: 1.7047
# Estimator 493/500, Train metric: 1.7010
# Estimator 494/500, Train metric: 1.6983
# Estimator 495/500, Train metric: 1.6946
# Estimator 496/500, Train metric: 1.6933
# Estimator 497/500, Train metric: 1.6912
# Estimator 498/500, Train metric: 1.6903
# Estimator 499/500, Train metric: 1.6895

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/pile_load_gendy_data/HyperParameter_Tuning/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/pile_load_gendy_data/HyperParameter_Tuning/test_results.xlsx")
# Out:
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# epoch 0  | loss: 648.07404| val_0_mse: 5534.90771|  0:00:00s
# epoch 1  | loss: 398.57074| val_0_mse: 9216.36621|  0:00:00s
# epoch 2  | loss: 303.32428| val_0_mse: 10751.01758|  0:00:00s
# epoch 3  | loss: 276.31079| val_0_mse: 11065.23047|  0:00:01s
# epoch 4  | loss: 219.60823| val_0_mse: 8614.99902|  0:00:01s
# epoch 5  | loss: 174.91129| val_0_mse: 5950.65771|  0:00:01s
# epoch 6  | loss: 175.16025| val_0_mse: 5055.20166|  0:00:01s
# epoch 7  | loss: 160.79065| val_0_mse: 5915.52637|  0:00:02s
# epoch 8  | loss: 140.4274| val_0_mse: 5906.38135|  0:00:02s
# epoch 9  | loss: 154.79163| val_0_mse: 5496.54199|  0:00:02s
# epoch 10 | loss: 125.2689| val_0_mse: 4307.22217|  0:00:02s
# epoch 11 | loss: 107.14195| val_0_mse: 4067.23584|  0:00:03s
# epoch 12 | loss: 100.9186| val_0_mse: 4242.95117|  0:00:03s
# epoch 13 | loss: 105.37605| val_0_mse: 4349.48486|  0:00:03s
# epoch 14 | loss: 91.04272| val_0_mse: 3555.53296|  0:00:04s
# epoch 15 | loss: 92.65572| val_0_mse: 3760.77808|  0:00:04s
# epoch 16 | loss: 91.22541| val_0_mse: 2871.00781|  0:00:05s
# epoch 17 | loss: 71.62218| val_0_mse: 1754.83826|  0:00:05s
# epoch 18 | loss: 76.18513| val_0_mse: 1600.45654|  0:00:05s
# epoch 19 | loss: 92.4212 | val_0_mse: 2499.74268|  0:00:06s
# epoch 20 | loss: 87.81472| val_0_mse: 2843.43896|  0:00:06s
# epoch 21 | loss: 78.08883| val_0_mse: 2358.14551|  0:00:06s
# epoch 22 | loss: 58.78664| val_0_mse: 1709.64551|  0:00:07s
# epoch 23 | loss: 67.7828 | val_0_mse: 2082.21655|  0:00:07s
# epoch 24 | loss: 51.84883| val_0_mse: 2028.71594|  0:00:07s
# epoch 25 | loss: 54.71154| val_0_mse: 2161.88892|  0:00:08s
# epoch 26 | loss: 50.84409| val_0_mse: 2490.37622|  0:00:08s
# epoch 27 | loss: 48.27736| val_0_mse: 2526.34839|  0:00:08s
# epoch 28 | loss: 64.57584| val_0_mse: 2567.76538|  0:00:08s
#
# Early stopping occurred at epoch 28 with best_epoch = 18 and best_val_0_mse = 1600.45654
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# WARNING:shap:Using 371 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/186 [00:00<?, ?it/s]
# Model PGBM is not supported or not available.
